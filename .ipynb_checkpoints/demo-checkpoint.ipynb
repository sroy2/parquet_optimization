# %% [markdown]
# # Recap on Storage, ROW vs COLUMN
#
# ![Screen%20Shot%202020-04-06%20at%2021.15.54.png](attachment:Screen%20Shot%202020-04-06%20at%2021.15.54.png)
#
# ![Screen%20Shot%202020-04-06%20at%2021.17.48.png](attachment:Screen%20Shot%202020-04-06%20at%2021.17.48.png)

# %% [markdown]
# # So what is parquet?
#
# ![Screen%20Shot%202020-04-06%20at%2021.19.53.png](attachment:Screen%20Shot%202020-04-06%20at%2021.19.53.png)

# %% [markdown]
# # Great, so about that lab?

# %%
import bench
import queries
